# %%
import tensorflow as tf
import numpy as np
from sys import stderr
from PIL import Image
import scipy
import scipy.misc
import scipy.io

# %%
VGG19_LAYERS = (
    'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1',

    'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',

    'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3',
    'relu3_3', 'conv3_4', 'relu3_4', 'pool3',

    'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'conv4_3',
    'relu4_3', 'conv4_4', 'relu4_4', 'pool4',

    'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'conv5_3',
    'relu5_3', 'conv5_4', 'relu5_4'
)

CONTENT_LAYERS = ('relu4_2', 'relu5_2')
STYLE_LAYERS = ('relu1_1', 'relu2_1', 'relu3_1', 'relu4_1', 'relu5_1')

try:
    reduce
except NameError:
    from functools import reduce

def load_net(data_path):
    data = scipy.io.loadmat(data_path)
    if not all(i in data for i in ('layers', 'classes', 'normalization')):
        raise ValueError("You're using the wrong VGG19 data. Please follow the instructions in the README to download the correct data.")
    mean = data['normalization'][0][0][0]
    mean_pixel = np.mean(mean, axis=(0, 1))
    weights = data['layers'][0]
    return weights, mean_pixel

def net_preloaded(weights, input_image, pooling):
    net = {}
    current = input_image
    for i, name in enumerate(VGG19_LAYERS):
        kind = name[:4]
        if kind == 'conv':
            kernels, bias = weights[i][0][0][0][0]
            # matconvnet: weights are [width, height, in_channels, out_channels]
            # tensorflow: weights are [height, width, in_channels, out_channels]
            kernels = np.transpose(kernels, (1, 0, 2, 3))
            bias = bias.reshape(-1)
            current = _conv_layer(current, kernels, bias)
        elif kind == 'relu':
            current = tf.nn.relu(current)
        elif kind == 'pool':
            current = _pool_layer(current, pooling)
        net[name] = current

    assert len(net) == len(VGG19_LAYERS)
    return net

def _conv_layer(input, weights, bias):
    conv = tf.nn.conv2d(input, tf.constant(weights), strides=(1, 1, 1, 1),
            padding='SAME')
    return tf.nn.bias_add(conv, bias)


def _pool_layer(input, pooling):
    if pooling == 'avg':
        return tf.nn.avg_pool(input, ksize=(1, 2, 2, 1), strides=(1, 2, 2, 1),
                padding='SAME')
    else:
        return tf.nn.max_pool(input, ksize=(1, 2, 2, 1), strides=(1, 2, 2, 1),
                padding='SAME')

def preprocess(image, mean_pixel):
    return image - mean_pixel


def unprocess(image, mean_pixel):
    return image + mean_pixel

# %%
def stylize(network, initial, initial_noiseblend, content, styles, preserve_colors, iterations,
        content_weight, content_weight_blend, style_weight, style_layer_weight_exp, style_blend_weights, tv_weight,
        learning_rate, beta1, beta2, epsilon, pooling,
        print_iterations=None, checkpoint_iterations=None):
    """
    Stylize images.
    This function yields tuples (iteration, image); `iteration` is None
    if this is the final image (the last iteration).  Other tuples are yielded
    every `checkpoint_iterations` iterations.
    :rtype: iterator[tuple[int|None,image]]
    """
    shape = (1,) + content.shape
    style_shapes = [(1,) + style.shape for style in styles]
    content_features = {}
    style_features = [{} for _ in styles]

    vgg_weights, vgg_mean_pixel = load_net(network)

    layer_weight = 1.0
    style_layers_weights = {}
    for style_layer in STYLE_LAYERS:
        style_layers_weights[style_layer] = layer_weight
        layer_weight *= style_layer_weight_exp

    # normalize style layer weights
    layer_weights_sum = 0
    for style_layer in STYLE_LAYERS:
        layer_weights_sum += style_layers_weights[style_layer]
    for style_layer in STYLE_LAYERS:
        style_layers_weights[style_layer] /= layer_weights_sum

    # compute content features in feedforward mode
    g = tf.Graph()
    with g.as_default(), g.device('/cpu:0'), tf.Session() as sess:
        image = tf.placeholder('float', shape=shape)
        net = net_preloaded(vgg_weights, image, pooling)
        content_pre = np.array([preprocess(content, vgg_mean_pixel)])
        for layer in CONTENT_LAYERS:
            content_features[layer] = net[layer].eval(feed_dict={image: content_pre})

    # compute style features in feedforward mode
    for i in range(len(styles)):
        g = tf.Graph()
        with g.as_default(), g.device('/cpu:0'), tf.Session() as sess:
            image = tf.placeholder('float', shape=style_shapes[i])
            net = net_preloaded(vgg_weights, image, pooling)
            style_pre = np.array([preprocess(styles[i], vgg_mean_pixel)])
            for layer in STYLE_LAYERS:
                features = net[layer].eval(feed_dict={image: style_pre})
                features = np.reshape(features, (-1, features.shape[3]))
                gram = np.matmul(features.T, features) / features.size
                style_features[i][layer] = gram

    initial_content_noise_coeff = 1.0 - initial_noiseblend

    # make stylized image using backpropogation
    with tf.Graph().as_default():
        if initial is None:
            noise = np.random.normal(size=shape, scale=np.std(content) * 0.1)
            initial = tf.random_normal(shape) * 0.256
        else:
            initial = np.array([preprocess(initial, vgg_mean_pixel)])
            initial = initial.astype('float32')
            noise = np.random.normal(size=shape, scale=np.std(content) * 0.1)
            initial = (initial) * initial_content_noise_coeff + (tf.random_normal(shape) * 0.256) * (1.0 - initial_content_noise_coeff)
        image = tf.Variable(initial)
        net = net_preloaded(vgg_weights, image, pooling)

        # content loss
        content_layers_weights = {}
        content_layers_weights['relu4_2'] = content_weight_blend
        content_layers_weights['relu5_2'] = 1.0 - content_weight_blend

        content_loss = 0
        content_losses = []
        for content_layer in CONTENT_LAYERS:
            content_losses.append(content_layers_weights[content_layer] * content_weight * (2 * tf.nn.l2_loss(
                    net[content_layer] - content_features[content_layer]) /
                    content_features[content_layer].size))
        content_loss += reduce(tf.add, content_losses)

        # style loss
        style_loss = 0
        for i in range(len(styles)):
            style_losses = []
            for style_layer in STYLE_LAYERS:
                layer = net[style_layer]
                _, height, width, number = map(lambda i: i.value, layer.get_shape())
                size = height * width * number
                feats = tf.reshape(layer, (-1, number))
                gram = tf.matmul(tf.transpose(feats), feats) / size
                style_gram = style_features[i][style_layer]
                style_losses.append(style_layers_weights[style_layer] * 2 * tf.nn.l2_loss(gram - style_gram) / style_gram.size)
            style_loss += style_weight * style_blend_weights[i] * reduce(tf.add, style_losses)

        # total variation denoising
        tv_y_size = _tensor_size(image[:,1:,:,:])
        tv_x_size = _tensor_size(image[:,:,1:,:])
        tv_loss = tv_weight * 2 * (
                (tf.nn.l2_loss(image[:,1:,:,:] - image[:,:shape[1]-1,:,:]) /
                    tv_y_size) +
                (tf.nn.l2_loss(image[:,:,1:,:] - image[:,:,:shape[2]-1,:]) /
                    tv_x_size))
        # overall loss
        loss = content_loss + style_loss + tv_loss

        # optimizer setup
        train_step = tf.train.AdamOptimizer(learning_rate, beta1, beta2, epsilon).minimize(loss)

        def print_progress():
            stderr.write('  content loss: %g\n' % content_loss.eval())
            stderr.write('    style loss: %g\n' % style_loss.eval())
            stderr.write('       tv loss: %g\n' % tv_loss.eval())
            stderr.write('    total loss: %g\n' % loss.eval())

        # optimization
        best_loss = float('inf')
        best = None
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            stderr.write('Optimization started...\n')
            if (print_iterations and print_iterations != 0):
                print_progress()
            for i in range(iterations):
                stderr.write('Iteration %4d/%4d\n' % (i + 1, iterations))
                train_step.run()

                last_step = (i == iterations - 1)
                if last_step or (print_iterations and i % print_iterations == 0):
                    print_progress()

                if (checkpoint_iterations and i % checkpoint_iterations == 0) or last_step:
                    this_loss = loss.eval()
                    if this_loss < best_loss:
                        best_loss = this_loss
                        best = image.eval()

                    img_out = unprocess(best.reshape(shape[1:]), vgg_mean_pixel)

                    if preserve_colors and preserve_colors == True:
                        original_image = np.clip(content, 0, 255)
                        styled_image = np.clip(img_out, 0, 255)

                        # Luminosity transfer steps:
                        # 1. Convert stylized RGB->grayscale accoriding to Rec.601 luma (0.299, 0.587, 0.114)
                        # 2. Convert stylized grayscale into YUV (YCbCr)
                        # 3. Convert original image into YUV (YCbCr)
                        # 4. Recombine (stylizedYUV.Y, originalYUV.U, originalYUV.V)
                        # 5. Convert recombined image from YUV back to RGB

                        # 1
                        styled_grayscale = rgb2gray(styled_image)
                        styled_grayscale_rgb = gray2rgb(styled_grayscale)

                        # 2
                        styled_grayscale_yuv = np.array(Image.fromarray(styled_grayscale_rgb.astype(np.uint8)).convert('YCbCr'))

                        # 3
                        original_yuv = np.array(Image.fromarray(original_image.astype(np.uint8)).convert('YCbCr'))

                        # 4
                        w, h, _ = original_image.shape
                        combined_yuv = np.empty((w, h, 3), dtype=np.uint8)
                        combined_yuv[..., 0] = styled_grayscale_yuv[..., 0]
                        combined_yuv[..., 1] = original_yuv[..., 1]
                        combined_yuv[..., 2] = original_yuv[..., 2]

                        # 5
                        img_out = np.array(Image.fromarray(combined_yuv, 'YCbCr').convert('RGB'))


                    yield (
                        (None if last_step else i),
                        img_out
                    )

# %%
def _tensor_size(tensor):
    from operator import mul
    return reduce(mul, (d.value for d in tensor.get_shape()), 1)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

def gray2rgb(gray):
    w, h = gray.shape
    rgb = np.empty((w, h, 3), dtype=np.float32)
    rgb[:, :, 2] = rgb[:, :, 1] = rgb[:, :, 0] = gray
    return rgb

# %%
def imgread(path):
    img = imread(path).astype(np.float)
    if len(img.shape) == 2:
        # grayscale
        img = np.dstack((img,img,img))
    elif img.shape[2] == 4:
        # PNG with alpha channel
        img = img[:,:,:3]
    return img


def imgsave(path, img):
    img = np.clip(img, 0, 255).astype(np.uint8)
    Image.fromarray(img).save(path, quality=95)

# %%
content_image = scipy.misc.imread('content.jpg')
style_images = [scipy.misc.imread(style) for style in ['style.jpg']]

# %%
target_shape = content_image.shape
for i in range(len(style_images)):
    style_scale = 1.0
    style_images[i] = scipy.misc.imresize(style_images[i], style_scale * target_shape[1] / style_images[i].shape[1])

style_blend_weights = [1.0/len(style_images) for _ in style_images]
initial = content_image
counter = 0

for iteration, image in stylize(
    network='imagenet-vgg-verydeep-19.mat',
    initial=initial,
    initial_noiseblend=1,
    content=content_image,
    styles=style_images,
    preserve_colors=None,
    iterations=1000,
    content_weight=5e0,
    content_weight_blend=1,
    style_weight=5e2,
    style_layer_weight_exp=1,
    style_blend_weights=[1.0/len(style_images) for _ in style_images],
    tv_weight=1e2,
    learning_rate=1e1,
    beta1=0.9,
    beta2=0.999,
    epsilon=1e-08,
    pooling='max',
    print_iterations=True,
    checkpoint_iterations=1
):
    counter += 1;
    scipy.misc.imsave('output' + str(counter) +  '.jpg', image)
# Out:
# Optimization started...
#   content loss: 1.14971e+06
#     style loss: 4.40616e+08
#        tv loss: 26.1934
#     total loss: 4.41766e+08
# Iteration    1/1000
#   content loss: 1.07131e+06
#     style loss: 4.13418e+08
#        tv loss: 20821.9
#     total loss: 4.1451e+08
# Iteration    2/1000
#   content loss: 1.25081e+06
#     style loss: 3.28639e+08
#        tv loss: 47886.7
#     total loss: 3.29938e+08
# Iteration    3/1000
#   content loss: 1.96858e+06
#     style loss: 2.14123e+08
#        tv loss: 84674.1
#     total loss: 2.16176e+08
# Iteration    4/1000
#   content loss: 3.3458e+06
#     style loss: 1.45174e+08
#        tv loss: 133645
#     total loss: 1.48654e+08
# Iteration    5/1000
#   content loss: 4.25563e+06
#     style loss: 1.30845e+08
#        tv loss: 179874
#     total loss: 1.35281e+08
# Iteration    6/1000
#   content loss: 4.19832e+06
#     style loss: 1.07054e+08
#        tv loss: 211425
#     total loss: 1.11464e+08
# Iteration    7/1000
#   content loss: 4.14657e+06
#     style loss: 8.60712e+07
#        tv loss: 234273
#     total loss: 9.0452e+07
# Iteration    8/1000
#   content loss: 4.367e+06
#     style loss: 6.8325e+07
#        tv loss: 254179
#     total loss: 7.29462e+07
# Iteration    9/1000
#   content loss: 4.76219e+06
#     style loss: 5.81533e+07
#        tv loss: 274169
#     total loss: 6.31896e+07
# Iteration   10/1000
#   content loss: 5.06625e+06
#     style loss: 5.31142e+07
#        tv loss: 293757
#     total loss: 5.84742e+07
# Iteration   11/1000
#   content loss: 5.12477e+06
#     style loss: 4.74906e+07
#        tv loss: 312067
#     total loss: 5.29274e+07
# Iteration   12/1000
#   content loss: 5.07157e+06
#     style loss: 4.29957e+07
#        tv loss: 329817
#     total loss: 4.83971e+07
# Iteration   13/1000
#   content loss: 5.05824e+06
#     style loss: 3.9463e+07
#        tv loss: 347211
#     total loss: 4.48684e+07
# Iteration   14/1000
#   content loss: 5.12304e+06
#     style loss: 3.58896e+07
#        tv loss: 363584
#     total loss: 4.13763e+07
# Iteration   15/1000
#   content loss: 5.20083e+06
#     style loss: 3.30413e+07
#        tv loss: 377783
#     total loss: 3.86199e+07
# Iteration   16/1000
#   content loss: 5.1979e+06
#     style loss: 3.05126e+07
#        tv loss: 388649
#     total loss: 3.60992e+07
# Iteration   17/1000
#   content loss: 5.11065e+06
#     style loss: 2.79271e+07
#        tv loss: 396124
#     total loss: 3.34339e+07
# Iteration   18/1000
#   content loss: 5.03931e+06
#     style loss: 2.57394e+07
#        tv loss: 401223
#     total loss: 3.11799e+07
# Iteration   19/1000
#   content loss: 5.06335e+06
#     style loss: 2.3565e+07
#        tv loss: 404959
#     total loss: 2.90333e+07
# Iteration   20/1000
#   content loss: 5.16957e+06
#     style loss: 2.14133e+07
#        tv loss: 407769
#     total loss: 2.69907e+07
# Iteration   21/1000
#   content loss: 5.27149e+06
#     style loss: 1.97314e+07
#        tv loss: 409529
#     total loss: 2.54124e+07
# Iteration   22/1000
#   content loss: 5.29035e+06
#     style loss: 1.82793e+07
#        tv loss: 410035
#     total loss: 2.39797e+07
# Iteration   23/1000
#   content loss: 5.2433e+06
#     style loss: 1.70747e+07
#        tv loss: 409561
#     total loss: 2.27276e+07
# Iteration   24/1000
#   content loss: 5.2101e+06
#     style loss: 1.60973e+07
#        tv loss: 408662
#     total loss: 2.17161e+07
# Iteration   25/1000
#   content loss: 5.23477e+06
#     style loss: 1.50277e+07
#        tv loss: 407634
#     total loss: 2.06701e+07
# Iteration   26/1000
#   content loss: 5.28316e+06
#     style loss: 1.4039e+07
#        tv loss: 406339
#     total loss: 1.97285e+07
# Iteration   27/1000
#   content loss: 5.2906e+06
#     style loss: 1.31761e+07
#        tv loss: 404448
#     total loss: 1.88712e+07
# Iteration   28/1000
#   content loss: 5.24394e+06
#     style loss: 1.23709e+07
#        tv loss: 401928
#     total loss: 1.80167e+07
# Iteration   29/1000
#   content loss: 5.20158e+06
#     style loss: 1.17028e+07
#        tv loss: 399116
#     total loss: 1.73035e+07
# Iteration   30/1000
#   content loss: 5.21062e+06
#     style loss: 1.1002e+07
#        tv loss: 396296
#     total loss: 1.6609e+07
# Iteration   31/1000
#   content loss: 5.24976e+06
#     style loss: 1.03551e+07
#        tv loss: 393406
#     total loss: 1.59983e+07
# Iteration   32/1000
#   content loss: 5.25959e+06
#     style loss: 9.81075e+06
#        tv loss: 390187
#     total loss: 1.54605e+07
# Iteration   33/1000
#   content loss: 5.22907e+06
#     style loss: 9.31815e+06
#        tv loss: 386618
#     total loss: 1.49338e+07
# Iteration   34/1000
#   content loss: 5.21025e+06
#     style loss: 8.8775e+06
#        tv loss: 383012
#     total loss: 1.44708e+07
# Iteration   35/1000
#   content loss: 5.23346e+06
#     style loss: 8.3977e+06
#        tv loss: 379602
#     total loss: 1.40108e+07
# Iteration   36/1000
#   content loss: 5.26761e+06
#     style loss: 7.97421e+06
#        tv loss: 376312
#     total loss: 1.36181e+07
# Iteration   37/1000
#   content loss: 5.26825e+06
#     style loss: 7.59599e+06
#        tv loss: 372970
#     total loss: 1.32372e+07
# Iteration   38/1000
#   content loss: 5.24699e+06
#     style loss: 7.2751e+06
#        tv loss: 369661
#     total loss: 1.28917e+07
# Iteration   39/1000
#   content loss: 5.2444e+06
#     style loss: 6.96158e+06
#        tv loss: 366592
#     total loss: 1.25726e+07
# Iteration   40/1000
#   content loss: 5.25984e+06
#     style loss: 6.64389e+06
#        tv loss: 363763
#     total loss: 1.22675e+07
# Iteration   41/1000
#   content loss: 5.25628e+06
#     style loss: 6.3723e+06
#        tv loss: 360991
#     total loss: 1.19896e+07
# Iteration   42/1000
#   content loss: 5.22697e+06
#     style loss: 6.1372e+06
#        tv loss: 358240
#     total loss: 1.17224e+07
# Iteration   43/1000
#   content loss: 5.21095e+06
#     style loss: 5.92263e+06
#        tv loss: 355701
#     total loss: 1.14893e+07
# Iteration   44/1000
#   content loss: 5.2241e+06
#     style loss: 5.68331e+06
#        tv loss: 353445
#     total loss: 1.12609e+07
# Iteration   45/1000
#   content loss: 5.23596e+06
#     style loss: 5.46716e+06
#        tv loss: 351307
#     total loss: 1.10544e+07
# Iteration   46/1000
#   content loss: 5.22255e+06
#     style loss: 5.28119e+06
#        tv loss: 349161
#     total loss: 1.08529e+07
# Iteration   47/1000
#   content loss: 5.2071e+06
#     style loss: 5.11983e+06
#        tv loss: 347113
#     total loss: 1.0674e+07
# Iteration   48/1000
#   content loss: 5.21141e+06
#     style loss: 4.94251e+06
#        tv loss: 345253
#     total loss: 1.04992e+07
# Iteration   49/1000
#   content loss: 5.21556e+06
#     style loss: 4.77893e+06
#        tv loss: 343449
#     total loss: 1.03379e+07
# Iteration   50/1000
#   content loss: 5.19825e+06
#     style loss: 4.64079e+06
#        tv loss: 341576
#     total loss: 1.01806e+07
# Iteration   51/1000
#   content loss: 5.17667e+06
#     style loss: 4.51996e+06
#        tv loss: 339745
#     total loss: 1.00364e+07
# Iteration   52/1000
#   content loss: 5.17221e+06
#     style loss: 4.38508e+06
#        tv loss: 338105
#     total loss: 9.8954e+06
# Iteration   53/1000
#   content loss: 5.17071e+06
#     style loss: 4.25804e+06
#        tv loss: 336609
#     total loss: 9.76536e+06
# Iteration   54/1000
#   content loss: 5.15431e+06
#     style loss: 4.14875e+06
#        tv loss: 335162
#     total loss: 9.63823e+06
# Iteration   55/1000
#   content loss: 5.13844e+06
#     style loss: 4.04866e+06
#        tv loss: 333821
#     total loss: 9.52092e+06
# Iteration   56/1000
#   content loss: 5.13974e+06
#     style loss: 3.93502e+06
#        tv loss: 332630
#     total loss: 9.40739e+06
# Iteration   57/1000
#   content loss: 5.14041e+06
#     style loss: 3.82923e+06
#        tv loss: 331453
#     total loss: 9.30109e+06
# Iteration   58/1000
#   content loss: 5.12617e+06
#     style loss: 3.73996e+06
#        tv loss: 330213
#     total loss: 9.19634e+06
# Iteration   59/1000
#   content loss: 5.11524e+06
#     style loss: 3.65551e+06
#        tv loss: 329046
#     total loss: 9.0998e+06
# Iteration   60/1000
#   content loss: 5.11685e+06
#     style loss: 3.56193e+06
#        tv loss: 328042
#     total loss: 9.00682e+06
# Iteration   61/1000
#   content loss: 5.11248e+06
#     style loss: 3.47899e+06
#        tv loss: 327088
#     total loss: 8.91856e+06
# Iteration   62/1000
#   content loss: 5.09532e+06
#     style loss: 3.41226e+06
#        tv loss: 326100
#     total loss: 8.83368e+06
# Iteration   63/1000
#   content loss: 5.0831e+06
#     style loss: 3.3446e+06
#        tv loss: 325132
#     total loss: 8.75284e+06
# Iteration   64/1000
#   content loss: 5.07786e+06
#     style loss: 3.27275e+06
#        tv loss: 324179
#     total loss: 8.67479e+06
# Iteration   65/1000
#   content loss: 5.06567e+06
#     style loss: 3.21062e+06
#        tv loss: 323180
#     total loss: 8.59947e+06
# Iteration   66/1000
#   content loss: 5.0521e+06
#     style loss: 3.15359e+06
#        tv loss: 322191
#     total loss: 8.52788e+06
# Iteration   67/1000
#   content loss: 5.04826e+06
#     style loss: 3.08825e+06
#        tv loss: 321293
#     total loss: 8.45781e+06
# Iteration   68/1000
#   content loss: 5.04288e+06
#     style loss: 3.0284e+06
#        tv loss: 320432
#     total loss: 8.39171e+06
# Iteration   69/1000
#   content loss: 5.02887e+06
#     style loss: 2.97849e+06
#        tv loss: 319564
#     total loss: 8.32692e+06
# Iteration   70/1000
#   content loss: 5.01914e+06
#     style loss: 2.9266e+06
#        tv loss: 318760
#     total loss: 8.2645e+06
# Iteration   71/1000
#   content loss: 5.0142e+06
#     style loss: 2.87269e+06
#        tv loss: 318011
#     total loss: 8.2049e+06
# Iteration   72/1000
#   content loss: 5.00195e+06
#     style loss: 2.82793e+06
#        tv loss: 317235
#     total loss: 8.14711e+06
# Iteration   73/1000
#   content loss: 4.98836e+06
#     style loss: 2.78651e+06
#        tv loss: 316455
#     total loss: 8.09132e+06
# Iteration   74/1000
#   content loss: 4.98279e+06
#     style loss: 2.73843e+06
#        tv loss: 315711
#     total loss: 8.03693e+06
# Iteration   75/1000
#   content loss: 4.9746e+06
#     style loss: 2.69506e+06
#        tv loss: 314933
#     total loss: 7.98459e+06
# Iteration   76/1000
#   content loss: 4.96099e+06
#     style loss: 2.65867e+06
#        tv loss: 314118
#     total loss: 7.93378e+06
# Iteration   77/1000
#   content loss: 4.95294e+06
#     style loss: 2.61804e+06
#        tv loss: 313348
#     total loss: 7.88434e+06
# Iteration   78/1000
#   content loss: 4.94614e+06
#     style loss: 2.57788e+06
#        tv loss: 312603
#     total loss: 7.83662e+06
# Iteration   79/1000
#   content loss: 4.93409e+06
#     style loss: 2.54411e+06
#        tv loss: 311836
#     total loss: 7.79003e+06
# Iteration   80/1000
#   content loss: 4.92449e+06
#     style loss: 2.50931e+06
#        tv loss: 311087
#     total loss: 7.74489e+06
# Iteration   81/1000
#   content loss: 4.91813e+06
#     style loss: 2.47252e+06
#        tv loss: 310360
#     total loss: 7.70101e+06
# Iteration   82/1000
#   content loss: 4.90697e+06
#     style loss: 2.44168e+06
#        tv loss: 309611
#     total loss: 7.65826e+06
# Iteration   83/1000
#   content loss: 4.89589e+06
#     style loss: 2.41194e+06
#        tv loss: 308872
#     total loss: 7.61670e+06
# Iteration   84/1000
#   content loss: 4.88877e+06
#     style loss: 2.3791e+06
#        tv loss: 308161
#     total loss: 7.57603e+06
# Iteration   85/1000
#   content loss: 4.87793e+06
#     style loss: 2.3511e+06
#        tv loss: 307424
#     total loss: 7.53645e+06
# Iteration   86/1000
#   content loss: 4.8666e+06
#     style loss: 2.32462e+06
#        tv loss: 306676
#     total loss: 7.4979e+06
# Iteration   87/1000
#   content loss: 4.85977e+06
#     style loss: 2.29443e+06
#        tv loss: 305953
#     total loss: 7.46015e+06
# Iteration   88/1000
#   content loss: 4.85080e+06
#     style loss: 2.26724e+06
#        tv loss: 305222
#     total loss: 7.42327e+06
# Iteration   89/1000
#   content loss: 4.84019e+06
#     style loss: 2.24265e+06
#        tv loss: 304491
#     total loss: 7.38734e+06
# Iteration   90/1000
#   content loss: 4.83237e+06
#     style loss: 2.21608e+06
#        tv loss: 303788
#     total loss: 7.35224e+06
# Iteration   91/1000
#   content loss: 4.82286e+06
#     style loss: 2.19202e+06
#        tv loss: 303087
#     total loss: 7.31796e+06
# Iteration   92/1000
#   content loss: 4.81286e+06
#     style loss: 2.16924e+06
#        tv loss: 302390
#     total loss: 7.28449e+06
# Iteration   93/1000
#   content loss: 4.80626e+06
#     style loss: 2.14376e+06
#        tv loss: 301712
#     total loss: 7.25174e+06
# Iteration   94/1000
#   content loss: 4.79784e+06
#     style loss: 2.12088e+06
#        tv loss: 301013
#     total loss: 7.21973e+06
# Iteration   95/1000
#   content loss: 4.78776e+06
#     style loss: 2.10038e+06
#        tv loss: 300297
#     total loss: 7.18844e+06
# Iteration   96/1000
#   content loss: 4.78072e+06
#     style loss: 2.07749e+06
#        tv loss: 299601
#     total loss: 7.15780e+06
# Iteration   97/1000
#   content loss: 4.77238e+06
#     style loss: 2.05656e+06
#        tv loss: 298902
#     total loss: 7.12785e+06
# Iteration   98/1000
#   content loss: 4.76348e+06
#     style loss: 2.0368e+06
#        tv loss: 298205
#     total loss: 7.09848e+06
# Iteration   99/1000
#   content loss: 4.75684e+06
#     style loss: 2.0154e+06
#        tv loss: 297527
#     total loss: 7.06977e+06
# Iteration  100/1000
#   content loss: 4.74825e+06
#     style loss: 1.99656e+06
#        tv loss: 296840
#     total loss: 7.04165e+06
# Iteration  101/1000
#   content loss: 4.73977e+06
#     style loss: 1.97817e+06
#        tv loss: 296154
#     total loss: 7.01409e+06
# Iteration  102/1000
#   content loss: 4.73283e+06
#     style loss: 1.95869e+06
#        tv loss: 295479
#     total loss: 6.987e+06
# Iteration  103/1000
#   content loss: 4.7241e+06
#     style loss: 1.94152e+06
#        tv loss: 294799
#     total loss: 6.96042e+06
# Iteration  104/1000
#   content loss: 4.717e+06
#     style loss: 1.92327e+06
#        tv loss: 294132
#     total loss: 6.9344e+06
# Iteration  105/1000
#   content loss: 4.71029e+06
#     style loss: 1.90515e+06
#        tv loss: 293472
#     total loss: 6.90892e+06
# Iteration  106/1000
#   content loss: 4.70188e+06
#     style loss: 1.88918e+06
#        tv loss: 292806
#     total loss: 6.88387e+06
# Iteration  107/1000
#   content loss: 4.69522e+06
#     style loss: 1.87191e+06
#        tv loss: 292156
#     total loss: 6.85929e+06
# Iteration  108/1000
#   content loss: 4.68747e+06
#     style loss: 1.85617e+06
#        tv loss: 291504
#     total loss: 6.83514e+06
# Iteration  109/1000
#   content loss: 4.67986e+06
#     style loss: 1.8407e+06
#        tv loss: 290854
#     total loss: 6.81142e+06
# Iteration  110/1000
#   content loss: 4.67331e+06
#     style loss: 1.82458e+06
#        tv loss: 290210
#     total loss: 6.7881e+06
# Iteration  111/1000
#   content loss: 4.66522e+06
#     style loss: 1.81043e+06
#        tv loss: 289558
#     total loss: 6.7652e+06
# Iteration  112/1000
#   content loss: 4.65841e+06
#     style loss: 1.79538e+06
#        tv loss: 288920
#     total loss: 6.74271e+06
# Iteration  113/1000
#   content loss: 4.65169e+06
#     style loss: 1.78065e+06
#        tv loss: 288288
#     total loss: 6.72062e+06
# Iteration  114/1000
#   content loss: 4.64431e+06
#     style loss: 1.76689e+06
#        tv loss: 287655
#     total loss: 6.69886e+06
# Iteration  115/1000
#   content loss: 4.63789e+06
#     style loss: 1.75251e+06
#        tv loss: 287030
#     total loss: 6.67744e+06
# Iteration  116/1000
#   content loss: 4.63033e+06
#     style loss: 1.73967e+06
#        tv loss: 286404
#     total loss: 6.65641e+06
# Iteration  117/1000
#   content loss: 4.62405e+06
#     style loss: 1.72589e+06
#        tv loss: 285794
#     total loss: 6.63573e+06
# Iteration  118/1000
#   content loss: 4.61732e+06
#     style loss: 1.71294e+06
#        tv loss: 285183
#     total loss: 6.61544e+06
# Iteration  119/1000
#   content loss: 4.61011e+06
#     style loss: 1.70083e+06
#        tv loss: 284565
#     total loss: 6.5955e+06
# Iteration  120/1000
#   content loss: 4.60382e+06
#     style loss: 1.68814e+06
#        tv loss: 283951
#     total loss: 6.57591e+06
# Iteration  121/1000
#   content loss: 4.59678e+06
#     style loss: 1.67651e+06
#        tv loss: 283333
#     total loss: 6.55662e+06
# Iteration  122/1000
#   content loss: 4.59072e+06
#     style loss: 1.66418e+06
#        tv loss: 282726
#     total loss: 6.53763e+06
# Iteration  123/1000
#   content loss: 4.58392e+06
#     style loss: 1.65289e+06
#        tv loss: 282119
#     total loss: 6.51893e+06
# Iteration  124/1000
#   content loss: 4.57751e+06
#     style loss: 1.64149e+06
#        tv loss: 281520
#     total loss: 6.50052e+06
# Iteration  125/1000
#   content loss: 4.57122e+06
#     style loss: 1.63022e+06
#        tv loss: 280925
#     total loss: 6.48236e+06
# Iteration  126/1000
#   content loss: 4.56432e+06
#     style loss: 1.61987e+06
#        tv loss: 280325
#     total loss: 6.46451e+06
# Iteration  127/1000
#   content loss: 4.55844e+06
#     style loss: 1.60875e+06
#        tv loss: 279732
#     total loss: 6.44693e+06
# Iteration  128/1000
#   content loss: 4.55144e+06
#     style loss: 1.59899e+06
#        tv loss: 279133
#     total loss: 6.42957e+06
# Iteration  129/1000
#   content loss: 4.54572e+06
#     style loss: 1.58818e+06
#        tv loss: 278546
#     total loss: 6.41244e+06
# Iteration  130/1000
#   content loss: 4.53881e+06
#     style loss: 1.57882e+06
#        tv loss: 277955
#     total loss: 6.39559e+06
# Iteration  131/1000
#   content loss: 4.53288e+06
#     style loss: 1.56878e+06
#        tv loss: 277373
#     total loss: 6.37903e+06
# Iteration  132/1000
#   content loss: 4.52638e+06
#     style loss: 1.55961e+06
#        tv loss: 276788
#     total loss: 6.36278e+06
# Iteration  133/1000
#   content loss: 4.52064e+06
#     style loss: 1.54994e+06
#        tv loss: 276209
#     total loss: 6.34679e+06
# Iteration  134/1000
#   content loss: 4.51436e+06
#     style loss: 1.54104e+06
#        tv loss: 275626
#     total loss: 6.33104e+06
# Iteration  135/1000
#   content loss: 4.50849e+06
#     style loss: 1.53199e+06
#        tv loss: 275048
#     total loss: 6.31553e+06
# Iteration  136/1000
#   content loss: 4.50277e+06
#     style loss: 1.52303e+06
#        tv loss: 274473
#     total loss: 6.30027e+06
# Iteration  137/1000
#   content loss: 4.49704e+06
#     style loss: 1.51432e+06
#        tv loss: 273899
#     total loss: 6.28526e+06
# Iteration  138/1000
#   content loss: 4.49151e+06
#     style loss: 1.50565e+06
#        tv loss: 273328
#     total loss: 6.27049e+06
# Iteration  139/1000
#   content loss: 4.48553e+06
#     style loss: 1.49765e+06
#        tv loss: 272754
#     total loss: 6.25593e+06
# Iteration  140/1000
#   content loss: 4.48042e+06
#     style loss: 1.48895e+06
#        tv loss: 272187
#     total loss: 6.24156e+06
# Iteration  141/1000
#   content loss: 4.47451e+06
#     style loss: 1.48127e+06
#        tv loss: 271614
#     total loss: 6.22739e+06
# Iteration  142/1000
#   content loss: 4.46983e+06
#     style loss: 1.47259e+06
#        tv loss: 271051
#     total loss: 6.21346e+06
# Iteration  143/1000
#   content loss: 4.4636e+06
#     style loss: 1.46566e+06
#        tv loss: 270481
#     total loss: 6.19974e+06
# Iteration  144/1000
#   content loss: 4.45952e+06
#     style loss: 1.45677e+06
#        tv loss: 269928
#     total loss: 6.18622e+06
# Iteration  145/1000
#   content loss: 4.45233e+06
#     style loss: 1.45126e+06
#        tv loss: 269355
#     total loss: 6.17294e+06
# Iteration  146/1000
#   content loss: 4.44989e+06
#     style loss: 1.44121e+06
#        tv loss: 268815
#     total loss: 6.15991e+06
# Iteration  147/1000
#   content loss: 4.44015e+06
#     style loss: 1.4388e+06
#        tv loss: 268230
#     total loss: 6.14718e+06
# Iteration  148/1000
#   content loss: 4.44262e+06
#     style loss: 1.42472e+06
#        tv loss: 267727
#     total loss: 6.13507e+06
# Iteration  149/1000
#   content loss: 4.42548e+06
#     style loss: 1.43173e+06
#        tv loss: 267098
#     total loss: 6.12431e+06
# Iteration  150/1000
#   content loss: 4.44119e+06
#     style loss: 1.40937e+06
#        tv loss: 266685
#     total loss: 6.11725e+06
# Iteration  151/1000
#   content loss: 4.40196e+06
#     style loss: 1.45279e+06
#        tv loss: 265922
#     total loss: 6.12068e+06
# Iteration  152/1000
#   content loss: 4.45573e+06
#     style loss: 1.43087e+06
#        tv loss: 265768
#     total loss: 6.15237e+06
# Iteration  153/1000
#   content loss: 4.35343e+06
#     style loss: 1.64827e+06
#        tv loss: 264602
#     total loss: 6.2663e+06
# Iteration  154/1000
#   content loss: 4.50664e+06
#     style loss: 1.74548e+06
#        tv loss: 265134
#     total loss: 6.51725e+06
# Iteration  155/1000
#   content loss: 4.27071e+06
#     style loss: 2.49886e+06
#        tv loss: 263085
#     total loss: 7.03265e+06
# Iteration  156/1000
#   content loss: 4.54576e+06
#     style loss: 2.18157e+06
#        tv loss: 264659
#     total loss: 6.99198e+06
# Iteration  157/1000
#   content loss: 4.30352e+06
#     style loss: 1.92743e+06
#        tv loss: 262640
#     total loss: 6.49359e+06
# Iteration  158/1000
#   content loss: 4.39301e+06
#     style loss: 1.39266e+06
#        tv loss: 263145
#     total loss: 6.04881e+06
# Iteration  159/1000
#   content loss: 4.49983e+06
#     style loss: 1.72535e+06
#        tv loss: 263733
#     total loss: 6.48891e+06
# Iteration  160/1000
#   content loss: 4.29436e+06
#     style loss: 1.90216e+06
#        tv loss: 261786
#     total loss: 6.45831e+06
# Iteration  161/1000
#   content loss: 4.39149e+06
#     style loss: 1.38228e+06
#        tv loss: 262271
#     total loss: 6.03604e+06
# Iteration  162/1000
#   content loss: 4.48492e+06
#     style loss: 1.64453e+06
#        tv loss: 262688
#     total loss: 6.39214e+06
# Iteration  163/1000
#   content loss: 4.30664e+06
#     style loss: 1.68852e+06
#        tv loss: 260829
#     total loss: 6.25599e+06
# Iteration  164/1000
#   content loss: 4.35392e+06
#     style loss: 1.44105e+06
#        tv loss: 260865
#     total loss: 6.05583e+06
# Iteration  165/1000
#   content loss: 4.46705e+06
#     style loss: 1.59127e+06
#        tv loss: 261416
#     total loss: 6.31974e+06
# Iteration  166/1000
#   content loss: 4.33642e+06
#     style loss: 1.45556e+06
#        tv loss: 259790
#     total loss: 6.05177e+06
# Iteration  167/1000
#   content loss: 4.32359e+06
#     style loss: 1.53723e+06
#        tv loss: 259175
#     total loss: 6.11999e+06
# Iteration  168/1000
#   content loss: 4.43721e+06
#     style loss: 1.44911e+06
#        tv loss: 259679
#     total loss: 6.146e+06
# Iteration  169/1000
#   content loss: 4.37404e+06
#     style loss: 1.34013e+06
#        tv loss: 258595
#     total loss: 5.97276e+06
# Iteration  170/1000
#   content loss: 4.30811e+06
#     style loss: 1.55346e+06
#        tv loss: 257474
#     total loss: 6.11904e+06
# Iteration  171/1000
#   content loss: 4.38755e+06
#     style loss: 1.32884e+06
#        tv loss: 257667
#     total loss: 5.97406e+06
# Iteration  172/1000
#   content loss: 4.39575e+06
#     style loss: 1.35065e+06
#        tv loss: 257194
#     total loss: 6.00359e+06
# Iteration  173/1000
#   content loss: 4.30959e+06
#     style loss: 1.45716e+06
#        tv loss: 255844
#     total loss: 6.02259e+06
# Iteration  174/1000
#   content loss: 4.33904e+06
#     style loss: 1.32285e+06
#        tv loss: 255551
#     total loss: 5.91744e+06
# Iteration  175/1000
#   content loss: 4.39135e+06
#     style loss: 1.3556e+06
#        tv loss: 255488
#     total loss: 6.00244e+06
# Iteration  176/1000
#   content loss: 4.32264e+06
#     style loss: 1.34159e+06
#        tv loss: 254353
#     total loss: 5.91858e+06
# Iteration  177/1000
#   content loss: 4.31057e+06
#     style loss: 1.35225e+06
#        tv loss: 253715
#     total loss: 5.91654e+06
# Iteration  178/1000
#   content loss: 4.36691e+06
#     style loss: 1.31935e+06
#        tv loss: 253704
#     total loss: 5.93997e+06
# Iteration  179/1000
#   content loss: 4.32874e+06
#     style loss: 1.2806e+06
#        tv loss: 252878
#     total loss: 5.86222e+06
# Iteration  180/1000
#   content loss: 4.29708e+06
#     style loss: 1.35534e+06
#        tv loss: 252090
#     total loss: 5.90451e+06
# Iteration  181/1000
#   content loss: 4.34207e+06
#     style loss: 1.27628e+06
#        tv loss: 251961
#     total loss: 5.8703e+06
# Iteration  182/1000
#   content loss: 4.32607e+06
#     style loss: 1.26256e+06
#        tv loss: 251312
#     total loss: 5.83995e+06
# Iteration  183/1000
#   content loss: 4.28876e+06
#     style loss: 1.33016e+06
#        tv loss: 250487
#     total loss: 5.86941e+06
# Iteration  184/1000
#   content loss: 4.3216e+06
#     style loss: 1.24854e+06
#        tv loss: 250274
#     total loss: 5.82042e+06
# Iteration  185/1000
#   content loss: 4.31692e+06
#     style loss: 1.25502e+06
#        tv loss: 249744
#     total loss: 5.82168e+06
# Iteration  186/1000
#   content loss: 4.2789e+06
#     style loss: 1.29954e+06
#        tv loss: 248946
#     total loss: 5.82739e+06
# Iteration  187/1000
#   content loss: 4.304e+06
#     style loss: 1.23566e+06
#        tv loss: 248694
#     total loss: 5.78836e+06
# Iteration  188/1000
#   content loss: 4.30485e+06
#     style loss: 1.24308e+06
#        tv loss: 248231
#     total loss: 5.79616e+06
# Iteration  189/1000
#   content loss: 4.2695e+06
#     style loss: 1.27424e+06
#        tv loss: 247471
#     total loss: 5.79122e+06
# Iteration  190/1000
#   content loss: 4.29054e+06
#     style loss: 1.22479e+06
#        tv loss: 247196
#     total loss: 5.76253e+06
# Iteration  191/1000
#   content loss: 4.29156e+06
#     style loss: 1.22842e+06
#        tv loss: 246756
#     total loss: 5.76673e+06
# Iteration  192/1000
#   content loss: 4.26211e+06
#     style loss: 1.25263e+06
#        tv loss: 246062
#     total loss: 5.7608e+06
# Iteration  193/1000
#   content loss: 4.27919e+06
#     style loss: 1.21295e+06
#        tv loss: 245768
#     total loss: 5.73791e+06
# Iteration  194/1000
#   content loss: 4.27537e+06
#     style loss: 1.21683e+06
#        tv loss: 245312
#     total loss: 5.73752e+06
# Iteration  195/1000
#   content loss: 4.25485e+06
#     style loss: 1.23327e+06
#        tv loss: 244701
#     total loss: 5.73282e+06
# Iteration  196/1000
#   content loss: 4.26762e+06
#     style loss: 1.20267e+06
#        tv loss: 244379
#     total loss: 5.71466e+06
# Iteration  197/1000
#   content loss: 4.25916e+06
#     style loss: 1.207e+06
#        tv loss: 243911
#     total loss: 5.71007e+06
# Iteration  198/1000
#   content loss: 4.24946e+06
#     style loss: 1.21361e+06
#        tv loss: 243402
#     total loss: 5.70647e+06
# Iteration  199/1000
#   content loss: 4.25400e+06
#     style loss: 1.19569e+06
#        tv loss: 243010
#     total loss: 5.6927e+06
# Iteration  200/1000
#   content loss: 4.24566e+06
#     style loss: 1.19563e+06
#        tv loss: 242539
#     total loss: 5.68383e+06
# Iteration  201/1000
#   content loss: 4.24453e+06
#     style loss: 1.19466e+06
#        tv loss: 242106
#     total loss: 5.68129e+06
# Iteration  202/1000
#   content loss: 4.23829e+06
#     style loss: 1.19247e+06
#        tv loss: 241642
#     total loss: 5.67241e+06
# Iteration  203/1000
#   content loss: 4.23623e+06
#     style loss: 1.18241e+06
#        tv loss: 241225
#     total loss: 5.65987e+06
# Iteration  204/1000
#   content loss: 4.23467e+06
#     style loss: 1.1797e+06
#        tv loss: 240790
#     total loss: 5.65516e+06
# Iteration  205/1000
#   content loss: 4.2254e+06
#     style loss: 1.18567e+06
#        tv loss: 240293
#     total loss: 5.65137e+06
# Iteration  206/1000
#   content loss: 4.22735e+06
#     style loss: 1.17343e+06
#        tv loss: 239900
#     total loss: 5.64068e+06
# Iteration  207/1000
#   content loss: 4.22083e+06
#     style loss: 1.17123e+06
#        tv loss: 239442
#     total loss: 5.6315e+06
# Iteration  208/1000
#   content loss: 4.21857e+06
#     style loss: 1.16977e+06
#        tv loss: 239006
#     total loss: 5.62734e+06
# Iteration  209/1000
#   content loss: 4.21348e+06
#     style loss: 1.1695e+06
#        tv loss: 238562
#     total loss: 5.62154e+06
# Iteration  210/1000
#   content loss: 4.21287e+06
#     style loss: 1.16116e+06
#        tv loss: 238146
#     total loss: 5.61217e+06
# Iteration  211/1000
#   content loss: 4.20718e+06
#     style loss: 1.15956e+06
#        tv loss: 237692
#     total loss: 5.60444e+06
# Iteration  212/1000
#   content loss: 4.20449e+06
#     style loss: 1.15812e+06
#        tv loss: 237267
#     total loss: 5.59988e+06
# Iteration  213/1000
#   content loss: 4.20262e+06
#     style loss: 1.15462e+06
#        tv loss: 236846
#     total loss: 5.59409e+06
# Iteration  214/1000
#   content loss: 4.19712e+06
#     style loss: 1.15251e+06
#        tv loss: 236393
#     total loss: 5.58603e+06
# Iteration  215/1000
#   content loss: 4.19699e+06
#     style loss: 1.14598e+06
#        tv loss: 235981
#     total loss: 5.57895e+06
# Iteration  216/1000
#   content loss: 4.18985e+06
#     style loss: 1.14829e+06
#        tv loss: 235521
#     total loss: 5.57366e+06
# Iteration  217/1000
#   content loss: 4.19265e+06
#     style loss: 1.14066e+06
#        tv loss: 235129
#     total loss: 5.56844e+06
# Iteration  218/1000
#   content loss: 4.18137e+06
#     style loss: 1.1462e+06
#        tv loss: 234638
#     total loss: 5.56221e+06
# Iteration  219/1000
#   content loss: 4.18930e+06
#     style loss: 1.13239e+06
#        tv loss: 234283
#     total loss: 5.55598e+06
# Iteration  220/1000
#   content loss: 4.17215e+06
#     style loss: 1.14596e+06
#        tv loss: 233760
#     total loss: 5.55187e+06
# Iteration  221/1000
#   content loss: 4.18925e+06
#     style loss: 1.12872e+06
#        tv loss: 233472
#     total loss: 5.55144e+06
# Iteration  222/1000
#   content loss: 4.15554e+06
#     style loss: 1.16907e+06
#        tv loss: 232847
#     total loss: 5.55746e+06
# Iteration  223/1000
#   content loss: 4.20117e+06
#     style loss: 1.14401e+06
#        tv loss: 232766
#     total loss: 5.57795e+06
# Iteration  224/1000
#   content loss: 4.12262e+06
#     style loss: 1.28244e+06
#        tv loss: 231837
#     total loss: 5.6369e+06
# Iteration  225/1000
#   content loss: 4.23347e+06
#     style loss: 1.28928e+06
#        tv loss: 232233
#     total loss: 5.75498e+06
# Iteration  226/1000
#   content loss: 4.06951e+06
#     style loss: 1.70457e+06
#        tv loss: 230721
#     total loss: 6.0048e+06
# Iteration  227/1000
#   content loss: 4.27588e+06
#     style loss: 1.65158e+06
#        tv loss: 231895
#     total loss: 6.15936e+06
# Iteration  228/1000
#   content loss: 4.04589e+06
#     style loss: 1.92243e+06
#        tv loss: 229947
#     total loss: 6.19827e+06
# Iteration  229/1000
#   content loss: 4.22538e+06
#     style loss: 1.24394e+06
#        tv loss: 231206
#     total loss: 5.70052e+06
# Iteration  230/1000
#   content loss: 4.17541e+06
#     style loss: 1.13155e+06
#        tv loss: 230618
#     total loss: 5.53757e+06
# Iteration  231/1000
#   content loss: 4.084e+06
#     style loss: 1.49206e+06
#        tv loss: 229674
#     total loss: 5.80573e+06
# Iteration  232/1000
#   content loss: 4.23346e+06
#     style loss: 1.27317e+06
#        tv loss: 230684
#     total loss: 5.73732e+06
# Iteration  233/1000
#   content loss: 4.13945e+06
#     style loss: 1.16229e+06
#        tv loss: 229625
#     total loss: 5.53136e+06
# Iteration  234/1000
#   content loss: 4.11442e+06
#     style loss: 1.27216e+06
#        tv loss: 229184
#     total loss: 5.61576e+06
# Iteration  235/1000
#   content loss: 4.21507e+06
#     style loss: 1.21409e+06
#        tv loss: 229780
#     total loss: 5.65895e+06
# Iteration  236/1000
#   content loss: 4.1283e+06
#     style loss: 1.17345e+06
#        tv loss: 228704
#     total loss: 5.53045e+06
# Iteration  237/1000
#   content loss: 4.12436e+06
#     style loss: 1.1926e+06
#        tv loss: 228369
#     total loss: 5.54533e+06
# Iteration  238/1000
#   content loss: 4.20106e+06
#     style loss: 1.1626e+06
#        tv loss: 228683
#     total loss: 5.59234e+06
# Iteration  239/1000
#   content loss: 4.12437e+06
#     style loss: 1.16216e+06
#        tv loss: 227603
#     total loss: 5.51413e+06
# Iteration  240/1000
#   content loss: 4.12628e+06
#     style loss: 1.15713e+06
#        tv loss: 227260
#     total loss: 5.51067e+06
# Iteration  241/1000
#   content loss: 4.18447e+06
#     style loss: 1.13099e+06
#        tv loss: 227386
#     total loss: 5.54284e+06
# Iteration  242/1000
#   content loss: 4.11541e+06
#     style loss: 1.14991e+06
#        tv loss: 226360
#     total loss: 5.49168e+06
# Iteration  243/1000
#   content loss: 4.1232e+06
#     style loss: 1.13456e+06
#        tv loss: 226020
#     total loss: 5.48378e+06
# Iteration  244/1000
#   content loss: 4.16469e+06
#     style loss: 1.11184e+06
#        tv loss: 225957
#     total loss: 5.50249e+06
# Iteration  245/1000
#   content loss: 4.10822e+06
#     style loss: 1.13507e+06
#        tv loss: 225029
#     total loss: 5.46832e+06
# Iteration  246/1000
#   content loss: 4.11831e+06
#     style loss: 1.11563e+06
#        tv loss: 224718
#     total loss: 5.45866e+06
# Iteration  247/1000
#   content loss: 4.14859e+06
#     style loss: 1.09615e+06
#        tv loss: 224584
#     total loss: 5.46932e+06
# Iteration  248/1000
#   content loss: 4.10076e+06
#     style loss: 1.12354e+06
#        tv loss: 223789
#     total loss: 5.44809e+06
# Iteration  249/1000
#   content loss: 4.11365e+06
#     style loss: 1.09974e+06
#        tv loss: 223517
#     total loss: 5.43691e+06
# Iteration  250/1000
#   content loss: 4.13099e+06
#     style loss: 1.08505e+06
#        tv loss: 223253
#     total loss: 5.43929e+06
# Iteration  251/1000
#   content loss: 4.09296e+06
#     style loss: 1.11319e+06
#        tv loss: 222536
#     total loss: 5.42868e+06
# Iteration  252/1000
#   content loss: 4.11371e+06
#     style loss: 1.08451e+06
#        tv loss: 222318
#     total loss: 5.42053e+06
# Iteration  253/1000
#   content loss: 4.11071e+06
#     style loss: 1.08118e+06
#        tv loss: 221909
#     total loss: 5.4138e+06
# Iteration  254/1000
#   content loss: 4.09133e+06
#     style loss: 1.09274e+06
#        tv loss: 221400
#     total loss: 5.40547e+06
# Iteration  255/1000
#   content loss: 4.10734e+06
#     style loss: 1.07607e+06
#        tv loss: 221177
#     total loss: 5.40459e+06
# Iteration  256/1000
#   content loss: 4.0937e+06
#     style loss: 1.08115e+06
#        tv loss: 220705
#     total loss: 5.39556e+06
# Iteration  257/1000
#   content loss: 4.08942e+06
#     style loss: 1.07184e+06
#        tv loss: 220338
#     total loss: 5.3816e+06
# Iteration  258/1000
#   content loss: 4.09817e+06
#     style loss: 1.06459e+06
#        tv loss: 220052
#     total loss: 5.38281e+06
# Iteration  259/1000
#   content loss: 4.07779e+06
#     style loss: 1.08541e+06
#        tv loss: 219536
#     total loss: 5.38274e+06
# Iteration  260/1000
#   content loss: 4.09411e+06
#     style loss: 1.05586e+06
#        tv loss: 219328
#     total loss: 5.36929e+06
# Iteration  261/1000
#   content loss: 4.07627e+06
#     style loss: 1.06598e+06
#        tv loss: 218852
#     total loss: 5.3611e+06
# Iteration  262/1000
#   content loss: 4.08017e+06
#     style loss: 1.0631e+06
#        tv loss: 218558
#     total loss: 5.36183e+06
# Iteration  263/1000
#   content loss: 4.08004e+06
#     style loss: 1.06274e+06
#        tv loss: 218245
#     total loss: 5.36103e+06
# Iteration  264/1000
#   content loss: 4.07173e+06
#     style loss: 1.06958e+06
#        tv loss: 217841
#     total loss: 5.35915e+06
# Iteration  265/1000
#   content loss: 4.06623e+06
#     style loss: 1.07823e+06
#        tv loss: 217503
#     total loss: 5.36197e+06
# Iteration  266/1000
#   content loss: 4.08669e+06
#     style loss: 1.07394e+06
#        tv loss: 217341
#     total loss: 5.37797e+06
# Iteration  267/1000
#   content loss: 4.03404e+06
#     style loss: 1.16868e+06
#        tv loss: 216628
#     total loss: 5.41935e+06
# Iteration  268/1000
#   content loss: 4.11074e+06
#     style loss: 1.16509e+06
#        tv loss: 216909
#     total loss: 5.49274e+06
# Iteration  269/1000
#   content loss: 4.00349e+06
#     style loss: 1.40958e+06
#        tv loss: 215828
#     total loss: 5.62889e+06
# Iteration  270/1000
#   content loss: 4.12874e+06
#     style loss: 1.36918e+06
#        tv loss: 216507
#     total loss: 5.71443e+06
# Iteration  271/1000
#   content loss: 3.9906e+06
#     style loss: 1.50908e+06
#        tv loss: 215272
#     total loss: 5.71495e+06
# Iteration  272/1000
#   content loss: 4.10703e+06
#     style loss: 1.13349e+06
#        tv loss: 216050
#     total loss: 5.45657e+06
# Iteration  273/1000
#   content loss: 4.04662e+06
#     style loss: 1.0699e+06
#        tv loss: 215397
#     total loss: 5.33192e+06
# Iteration  274/1000
#   content loss: 4.0322e+06
#     style loss: 1.19516e+06
#        tv loss: 215105
#     total loss: 5.44246e+06
# Iteration  275/1000
#   content loss: 4.10043e+06
#     style loss: 1.17521e+06
#        tv loss: 215471
#     total loss: 5.49111e+06
# Iteration  276/1000
#   content loss: 4.01802e+06
#     style loss: 1.16879e+06
#        tv loss: 214478
#     total loss: 5.40128e+06
# Iteration  277/1000
#   content loss: 4.05853e+06
#     style loss: 1.069e+06
#        tv loss: 214646
#     total loss: 5.34218e+06
# Iteration  278/1000
#   content loss: 4.07846e+06
#     style loss: 1.09149e+06
#        tv loss: 214551
#     total loss: 5.3845e+06
# Iteration  279/1000
#   content loss: 4.01186e+06
#     style loss: 1.16805e+06
#        tv loss: 213681
#     total loss: 5.39359e+06
# Iteration  280/1000
#   content loss: 4.07143e+06
#     style loss: 1.05762e+06
#        tv loss: 213941
#     total loss: 5.34299e+06
# Iteration  281/1000
#   content loss: 4.05448e+06
#     style loss: 1.06572e+06
#        tv loss: 213437
#     total loss: 5.33364e+06
# Iteration  282/1000
#   content loss: 4.01991e+06
#     style loss: 1.11208e+06
#        tv loss: 212826
#     total loss: 5.34482e+06
# Iteration  283/1000
#   content loss: 4.06747e+06
#     style loss: 1.04569e+06
#        tv loss: 212957
#     total loss: 5.32612e+06
# Iteration  284/1000
#   content loss: 4.03423e+06
#     style loss: 1.06685e+06
#        tv loss: 212296
#     total loss: 5.31337e+06
# Iteration  285/1000
#   content loss: 4.02747e+06
#     style loss: 1.07302e+06
#        tv loss: 211904
#     total loss: 5.31239e+06
# Iteration  286/1000
#   content loss: 4.05258e+06
#     style loss: 1.0341e+06
#        tv loss: 211793
#     total loss: 5.29847e+06
# Iteration  287/1000
#   content loss: 4.02515e+06
#     style loss: 1.05489e+06
#        tv loss: 211178
#     total loss: 5.29122e+06
# Iteration  288/1000
#   content loss: 4.02868e+06
#     style loss: 1.0544e+06
#        tv loss: 210916
#     total loss: 5.294e+06
# Iteration  289/1000
#   content loss: 4.04092e+06
#     style loss: 1.02454e+06
#        tv loss: 210688
#     total loss: 5.27615e+06
# Iteration  290/1000
#   content loss: 4.01668e+06
#     style loss: 1.03764e+06
#        tv loss: 210151
#     total loss: 5.26447e+06
# Iteration  291/1000
#   content loss: 4.02766e+06
#     style loss: 1.03918e+06
#        tv loss: 209945
#     total loss: 5.27679e+06
# Iteration  292/1000
#   content loss: 4.02194e+06
#     style loss: 1.03486e+06
#        tv loss: 209567
#     total loss: 5.26637e+06
# Iteration  293/1000
#   content loss: 4.0197e+06
#     style loss: 1.0149e+06
#        tv loss: 209221
#     total loss: 5.24382e+06
# Iteration  294/1000
#   content loss: 4.01262e+06
#     style loss: 1.0297e+06
#        tv loss: 208880
#     total loss: 5.2512e+06
# Iteration  295/1000
#   content loss: 4.02097e+06
#     style loss: 1.02512e+06
#        tv loss: 208612
#     total loss: 5.2547e+06
# Iteration  296/1000
#   content loss: 4.00686e+06
#     style loss: 1.02279e+06
#        tv loss: 208232
#     total loss: 5.23787e+06
# Iteration  297/1000
#   content loss: 4.01452e+06
#     style loss: 1.01568e+06
#        tv loss: 207975
#     total loss: 5.23817e+06
# Iteration  298/1000
#   content loss: 3.99797e+06
#     style loss: 1.04388e+06
#        tv loss: 207583
#     total loss: 5.24944e+06
# Iteration  299/1000
#   content loss: 4.02407e+06
#     style loss: 1.01928e+06
#        tv loss: 207473
#     total loss: 5.25083e+06
# Iteration  300/1000
#   content loss: 3.9701e+06
#     style loss: 1.09907e+06
#        tv loss: 206819
#     total loss: 5.27598e+06
# Iteration  301/1000
#   content loss: 4.0498e+06
#     style loss: 1.09e+06
#        tv loss: 207090
#     total loss: 5.34689e+06
# Iteration  302/1000
#   content loss: 3.9341e+06
#     style loss: 1.35512e+06
#        tv loss: 206038
#     total loss: 5.49526e+06
# Iteration  303/1000
#   content loss: 4.08401e+06
#     style loss: 1.37353e+06
#        tv loss: 206828
#     total loss: 5.66437e+06
# Iteration  304/1000
#   content loss: 3.89713e+06
#     style loss: 1.79568e+06
#        tv loss: 205291
#     total loss: 5.8981e+06
# Iteration  305/1000
#   content loss: 4.09240e+06
#     style loss: 1.40488e+06
#        tv loss: 206636
#     total loss: 5.70393e+06
# Iteration  306/1000
#   content loss: 3.93898e+06
#     style loss: 1.23425e+06
#        tv loss: 205312
#     total loss: 5.37855e+06
# Iteration  307/1000
#   content loss: 3.99659e+06
#     style loss: 1.08028e+06
#        tv loss: 205818
#     total loss: 5.28269e+06
# Iteration  308/1000
#   content loss: 4.05754e+06
#     style loss: 1.22173e+06
#        tv loss: 206165
#     total loss: 5.48544e+06
# Iteration  309/1000
#   content loss: 3.93439e+06
#     style loss: 1.3638e+06
#        tv loss: 205013
#     total loss: 5.5032e+06
# Iteration  310/1000
#   content loss: 4.02417e+06
#     style loss: 1.07233e+06
#        tv loss: 205680
#     total loss: 5.30218e+06
# Iteration  311/1000
#   content loss: 4.04398e+06
#     style loss: 1.12245e+06
#        tv loss: 205638
#     total loss: 5.37207e+06
# Iteration  312/1000
#   content loss: 3.92096e+06
#     style loss: 1.3783e+06
#        tv loss: 204431
#     total loss: 5.50369e+06
# Iteration  313/1000
#   content loss: 4.05504e+06
#     style loss: 1.14804e+06
#        tv loss: 205428
#     total loss: 5.40851e+06
# Iteration  314/1000
#   content loss: 3.98889e+06
#     style loss: 1.23779e+06
#        tv loss: 204592
#     total loss: 5.43127e+06
# Iteration  315/1000
#   content loss: 3.96528e+06
#     style loss: 1.30723e+06
#        tv loss: 204227
#     total loss: 5.47674e+06
# Iteration  316/1000
#   content loss: 4.0206e+06
#     style loss: 1.12464e+06
#        tv loss: 204461
#     total loss: 5.3497e+06
# Iteration  317/1000
#   content loss: 3.9995e+06
#     style loss: 1.06322e+06
#        tv loss: 204021
#     total loss: 5.26674e+06
# Iteration  318/1000
#   content loss: 3.9589e+06
#     style loss: 1.12109e+06
#        tv loss: 203498
#     total loss: 5.28349e+06
# Iteration  319/1000
#   content loss: 4.01564e+06
#     style loss: 1.0745e+06
#        tv loss: 203759
#     total loss: 5.2939e+06
# Iteration  320/1000
#   content loss: 3.99043e+06
#     style loss: 1.07402e+06
#        tv loss: 203201
#     total loss: 5.26766e+06
# Iteration  321/1000
#   content loss: 3.94546e+06
#     style loss: 1.11461e+06
#        tv loss: 202581
#     total loss: 5.26265e+06
# Iteration  322/1000
#   content loss: 4.03001e+06
#     style loss: 1.04876e+06
#        tv loss: 203092
#     total loss: 5.28186e+06
# Iteration  323/1000
#   content loss: 3.95873e+06
#     style loss: 1.06946e+06
#        tv loss: 202178
#     total loss: 5.23037e+06
# Iteration  324/1000
#   content loss: 3.9635e+06
#     style loss: 1.03315e+06
#        tv loss: 201940
#     total loss: 5.19858e+06
# Iteration  325/1000
#   content loss: 4.01209e+06
#     style loss: 1.02899e+06
#        tv loss: 202116
#     total loss: 5.2432e+06
# Iteration  326/1000
#   content loss: 3.94793e+06
#     style loss: 1.05243e+06
#        tv loss: 201232
#     total loss: 5.20159e+06
# Iteration  327/1000
#   content loss: 3.96679e+06
#     style loss: 1.0135e+06
#        tv loss: 201111
#     total loss: 5.1814e+06
# Iteration  328/1000
#   content loss: 3.99051e+06
#     style loss: 1.04145e+06
#        tv loss: 201092
#     total loss: 5.23306e+06
# Iteration  329/1000
#   content loss: 3.95782e+06
#     style loss: 1.03314e+06
#        tv loss: 200469
#     total loss: 5.19143e+06
# Iteration  330/1000
#   content loss: 3.94752e+06
#     style loss: 1.01935e+06
#        tv loss: 200134
#     total loss: 5.16701e+06
# Iteration  331/1000
#   content loss: 3.99829e+06
#     style loss: 1.00046e+06
#        tv loss: 200322
#     total loss: 5.19907e+06
# Iteration  332/1000
#   content loss: 3.93419e+06
#     style loss: 1.03511e+06
#        tv loss: 199490
#     total loss: 5.16879e+06
# Iteration  333/1000
#   content loss: 3.96238e+06
#     style loss: 992474
#        tv loss: 199436
#     total loss: 5.15429e+06
# Iteration  334/1000
#   content loss: 3.96765e+06
#     style loss: 995540
#        tv loss: 199277
#     total loss: 5.16246e+06
# Iteration  335/1000
#   content loss: 3.94779e+06
#     style loss: 992018
#        tv loss: 198830
#     total loss: 5.13864e+06
# Iteration  336/1000
#   content loss: 3.95136e+06
#     style loss: 993400
#        tv loss: 198590
#     total loss: 5.14335e+06
# Iteration  337/1000
#   content loss: 3.95829e+06
#     style loss: 985217
#        tv loss: 198445
#     total loss: 5.14195e+06
# Iteration  338/1000
#   content loss: 3.94941e+06
#     style loss: 970946
#        tv loss: 198105
#     total loss: 5.11846e+06
# Iteration  339/1000
#   content loss: 3.94041e+06
#     style loss: 990851
#        tv loss: 197799
#     total loss: 5.12906e+06
# Iteration  340/1000
#   content loss: 3.95284e+06
#     style loss: 980477
#        tv loss: 197717
#     total loss: 5.13103e+06
# Iteration  341/1000
#   content loss: 3.93877e+06
#     style loss: 978370
#        tv loss: 197367
#     total loss: 5.11451e+06
# Iteration  342/1000
#   content loss: 3.94487e+06
#     style loss: 980104
#        tv loss: 197191
#     total loss: 5.12217e+06
# Iteration  343/1000
#   content loss: 3.92707e+06
#     style loss: 1.00953e+06
#        tv loss: 196876
#     total loss: 5.13347e+06
# Iteration  344/1000
#   content loss: 3.96538e+06
#     style loss: 988646
#        tv loss: 196917
#     total loss: 5.15094e+06
# Iteration  345/1000
#   content loss: 3.88819e+06
#     style loss: 1.1375e+06
#        tv loss: 196156
#     total loss: 5.22184e+06
# Iteration  346/1000
#   content loss: 3.99735e+06
#     style loss: 1.14121e+06
#        tv loss: 196787
#     total loss: 5.33534e+06
# Iteration  347/1000
#   content loss: 3.85704e+06
#     style loss: 1.48757e+06
#        tv loss: 195530
#     total loss: 5.54014e+06
# Iteration  348/1000
#   content loss: 4.01307e+06
#     style loss: 1.42657e+06
#        tv loss: 196610
#     total loss: 5.63625e+06
# Iteration  349/1000
#   content loss: 3.86352e+06
#     style loss: 1.52061e+06
#        tv loss: 195404
#     total loss: 5.57953e+06
# Iteration  350/1000
#   content loss: 3.96821e+06
#     style loss: 1.02953e+06
#        tv loss: 196333
#     total loss: 5.19408e+06
# Iteration  351/1000
#   content loss: 3.94652e+06
#     style loss: 990941
#        tv loss: 196143
#     total loss: 5.13361e+06
# Iteration  352/1000
#   content loss: 3.88728e+06
#     style loss: 1.27518e+06
#        tv loss: 195613
#     total loss: 5.35808e+06
# Iteration  353/1000
#   content loss: 3.98815e+06
#     style loss: 1.12582e+06
#        tv loss: 196367
#     total loss: 5.31033e+06
# Iteration  354/1000
#   content loss: 3.90452e+06
#     style loss: 1.052e+06
#        tv loss: 195585
#     total loss: 5.15211e+06
# Iteration  355/1000
#   content loss: 3.93103e+06
#     style loss: 1.05721e+06
#        tv loss: 195739
#     total loss: 5.18398e+06
# Iteration  356/1000
#   content loss: 3.96659e+06
#     style loss: 1.07638e+06
#        tv loss: 195839
#     total loss: 5.23880e+06
# Iteration  357/1000
#   content loss: 3.89891e+06
#     style loss: 1.08306e+06
#        tv loss: 195143
#     total loss: 5.17711e+06
# Iteration  358/1000
#   content loss: 3.95243e+06
#     style loss: 995577
#        tv loss: 195475
#     total loss: 5.14348e+06
# Iteration  359/1000
#   content loss: 3.94326e+06
#     style loss: 1.03112e+06
#        tv loss: 195120
#     total loss: 5.1695e+06
# Iteration  360/1000
#   content loss: 3.91031e+06
#     style loss: 1.05503e+06
#        tv loss: 194543
#     total loss: 5.15988e+06
# Iteration  361/1000
#   content loss: 3.94366e+06
#     style loss: 990648
#        tv loss: 194663
#     total loss: 5.12897e+06
# Iteration  362/1000
#   content loss: 3.94001e+06
#     style loss: 989260
#        tv loss: 194298
#     total loss: 5.12357e+06
# Iteration  363/1000
#   content loss: 3.89802e+06
#     style loss: 1.05019e+06
#        tv loss: 193716
#     total loss: 5.14193e+06
# Iteration  364/1000
#   content loss: 3.94651e+06
#     style loss: 986126
#        tv loss: 193864
#     total loss: 5.1265e+06
# Iteration  365/1000
#   content loss: 3.91888e+06
#     style loss: 1.00742e+06
#        tv loss: 193398
#     total loss: 5.1197e+06
# Iteration  366/1000
#   content loss: 3.90788e+06
#     style loss: 1.05446e+06
#        tv loss: 192966
#     total loss: 5.15531e+06
# Iteration  367/1000
#   content loss: 3.92649e+06
#     style loss: 1.04404e+06
#        tv loss: 193042
#     total loss: 5.16357e+06
# Iteration  368/1000
#   content loss: 3.92795e+06
#     style loss: 1.03474e+06
#        tv loss: 192698
#     total loss: 5.15539e+06
# Iteration  369/1000
#   content loss: 3.88363e+06
#     style loss: 1.10392e+06
#        tv loss: 192210
#     total loss: 5.17977e+06
# Iteration  370/1000
#   content loss: 3.94747e+06
#     style loss: 1.01781e+06
#        tv loss: 192400
#     total loss: 5.15768e+06
# Iteration  371/1000
#   content loss: 3.8845e+06
#     style loss: 1.03362e+06
#        tv loss: 191728
#     total loss: 5.10985e+06
# Iteration  372/1000
#   content loss: 3.92681e+06
#     style loss: 976717
#        tv loss: 191780
#     total loss: 5.0953e+06
# Iteration  373/1000
#   content loss: 3.89828e+06
#     style loss: 1.02714e+06
#        tv loss: 191355
#     total loss: 5.11677e+06
# Iteration  374/1000
#   content loss: 3.92463e+06
#     style loss: 997581
#        tv loss: 191408
#     total loss: 5.11362e+06
# Iteration  375/1000
#   content loss: 3.88208e+06
#     style loss: 1.03665e+06
#        tv loss: 190812
#     total loss: 5.10954e+06
# Iteration  376/1000
#   content loss: 3.93135e+06
#     style loss: 996796
#        tv loss: 191089
#     total loss: 5.11923e+06
# Iteration  377/1000
#   content loss: 3.87489e+06
#     style loss: 1.03309e+06
#        tv loss: 190451
#     total loss: 5.09843e+06
# Iteration  378/1000
#   content loss: 3.92224e+06
#     style loss: 943234
#        tv loss: 190583
#     total loss: 5.05606e+06
# Iteration  379/1000
#   content loss: 3.88849e+06
#     style loss: 983459
# ...
#   content loss: 3.8045e+06
#     style loss: 918703
#        tv loss: 177892
#     total loss: 4.9011e+06
# Iteration  480/1000
#   content loss: 3.82059e+06
#     style loss: 894202
#        tv loss: 177871
#     total loss: 4.89266e+06
# Iteration  481/1000
#   content loss: 3.81488e+06
#     style loss: 886846
#        tv loss: 177638
#     total loss: 4.87937e+06
# Iteration  482/1000
#   content loss: 3.80674e+06
#     style loss: 895908
#        tv loss: 177387
#     total loss: 4.88004e+06
# Iteration  483/1000
#   content loss: 3.81436e+06
#     style loss: 893189
#        tv loss: 177356
#     total loss: 4.8849e+06
# Iteration  484/1000
#   content loss: 3.80764e+06
#     style loss: 893840
#        tv loss: 177080
#     total loss: 4.87856e+06
# Iteration  485/1000
#   content loss: 3.80334e+06
#     style loss: 886889
#        tv loss: 176893
#     total loss: 4.86712e+06
# Iteration  486/1000
#   content loss: 3.81414e+06
#     style loss: 877969
#        tv loss: 176842
#     total loss: 4.86895e+06
# Iteration  487/1000
#   content loss: 3.7915e+06
#     style loss: 909630
#        tv loss: 176549
#     total loss: 4.87768e+06
# Iteration  488/1000
#   content loss: 3.81902e+06
#     style loss: 884581
#        tv loss: 176549
#     total loss: 4.88015e+06
# Iteration  489/1000
#   content loss: 3.77836e+06
#     style loss: 935527
#        tv loss: 176142
#     total loss: 4.89003e+06
# Iteration  490/1000
#   content loss: 3.82929e+06
#     style loss: 917643
#        tv loss: 176342
#     total loss: 4.92327e+06
# Iteration  491/1000
#   content loss: 3.7617e+06
#     style loss: 1.0613e+06
#        tv loss: 175831
#     total loss: 4.99883e+06
# Iteration  492/1000
#   content loss: 3.84539e+06
#     style loss: 1.07405e+06
#        tv loss: 176119
#     total loss: 5.09555e+06
# Iteration  493/1000
#   content loss: 3.73835e+06
#     style loss: 1.30977e+06
#        tv loss: 175442
#     total loss: 5.22356e+06
# Iteration  494/1000
#   content loss: 3.86461e+06
#     style loss: 1.15004e+06
#        tv loss: 176133
#     total loss: 5.19078e+06
# Iteration  495/1000
#   content loss: 3.73533e+06
#     style loss: 1.16748e+06
#        tv loss: 175207
#     total loss: 5.07802e+06
# Iteration  496/1000
#   content loss: 3.83717e+06
#     style loss: 941676
#        tv loss: 175993
#     total loss: 4.95484e+06
# Iteration  497/1000
#   content loss: 3.79208e+06
#     style loss: 1.05084e+06
#        tv loss: 175487
#     total loss: 5.0184e+06
# Iteration  498/1000
#   content loss: 3.77972e+06
#     style loss: 1.08176e+06
#        tv loss: 175515
#     total loss: 5.037e+06
# Iteration  499/1000
#   content loss: 3.81994e+06
#     style loss: 904269
#        tv loss: 175682
#     total loss: 4.89989e+06
# Iteration  500/1000
#   content loss: 3.78247e+06
#     style loss: 937316
#        tv loss: 175321
#     total loss: 4.89511e+06
# Iteration  501/1000
#   content loss: 3.80323e+06
#     style loss: 1.00256e+06
#        tv loss: 175524
#     total loss: 4.98132e+06
# Iteration  502/1000
#   content loss: 3.79516e+06
#     style loss: 948310
#        tv loss: 175235
#     total loss: 4.91871e+06
# Iteration  503/1000
#   content loss: 3.80166e+06
#     style loss: 894634
#        tv loss: 175248
#     total loss: 4.87155e+06
# Iteration  504/1000
#   content loss: 3.7867e+06
#     style loss: 957939
#        tv loss: 175121
#     total loss: 4.91976e+06
# Iteration  505/1000
#   content loss: 3.80149e+06
#     style loss: 916708
#        tv loss: 175005
#     total loss: 4.8932e+06
# Iteration  506/1000
#   content loss: 3.7945e+06
#     style loss: 900417
#        tv loss: 174866
#     total loss: 4.86978e+06
# Iteration  507/1000
#   content loss: 3.78139e+06
#     style loss: 942802
#        tv loss: 174665
#     total loss: 4.89886e+06
# Iteration  508/1000
#   content loss: 3.80303e+06
#     style loss: 896809
#        tv loss: 174596
#     total loss: 4.87443e+06
# Iteration  509/1000
#   content loss: 3.78127e+06
#     style loss: 903099
#        tv loss: 174300
#     total loss: 4.85867e+06
# Iteration  510/1000
#   content loss: 3.78876e+06
#     style loss: 906524
#        tv loss: 174261
#     total loss: 4.86955e+06
# Iteration  511/1000
#   content loss: 3.79256e+06
#     style loss: 882341
#        tv loss: 174056
#     total loss: 4.84896e+06
# Iteration  512/1000
#   content loss: 3.77446e+06
#     style loss: 895740
#        tv loss: 173808
#     total loss: 4.84401e+06
# Iteration  513/1000
#   content loss: 3.79829e+06
#     style loss: 885888
#        tv loss: 173865
#     total loss: 4.85804e+06
# Iteration  514/1000
#   content loss: 3.76748e+06
#     style loss: 907787
#        tv loss: 173393
#     total loss: 4.84866e+06
# Iteration  515/1000
#   content loss: 3.79893e+06
#     style loss: 879652
#        tv loss: 173521
#     total loss: 4.8521e+06
# Iteration  516/1000
#   content loss: 3.76032e+06
#     style loss: 944514
#        tv loss: 173098
#     total loss: 4.87793e+06
# Iteration  517/1000
#   content loss: 3.80737e+06
#     style loss: 907802
#        tv loss: 173250
#     total loss: 4.88842e+06
# Iteration  518/1000
#   content loss: 3.73938e+06
#     style loss: 1.00993e+06
#        tv loss: 172655
#     total loss: 4.92197e+06
# Iteration  519/1000
#   content loss: 3.8232e+06
#     style loss: 974454
#        tv loss: 173202
#     total loss: 4.97086e+06
# Iteration  520/1000
#   content loss: 3.72677e+06
#     style loss: 1.11354e+06
#        tv loss: 172290
#     total loss: 5.0126e+06
# Iteration  521/1000
#   content loss: 3.81441e+06
#     style loss: 984522
#        tv loss: 172988
#     total loss: 4.97192e+06
# Iteration  522/1000
#   content loss: 3.75526e+06
#     style loss: 979235
#        tv loss: 172418
#     total loss: 4.90691e+06
# Iteration  523/1000
#   content loss: 3.76924e+06
#     style loss: 896878
#        tv loss: 172448
#     total loss: 4.83857e+06
# Iteration  524/1000
#   content loss: 3.80067e+06
#     style loss: 870009
#        tv loss: 172674
#     total loss: 4.84336e+06
# Iteration  525/1000
#   content loss: 3.7355e+06
#     style loss: 1.00274e+06
#        tv loss: 172029
#     total loss: 4.91027e+06
# Iteration  526/1000
#   content loss: 3.81163e+06
#     style loss: 939932
#        tv loss: 172549
#     total loss: 4.92411e+06
# Iteration  527/1000
#   content loss: 3.7383e+06
#     style loss: 971075
#        tv loss: 171944
#     total loss: 4.88131e+06
# Iteration  528/1000
#   content loss: 3.79262e+06
#     style loss: 895842
#        tv loss: 172244
#     total loss: 4.8607e+06
# Iteration  529/1000
#   content loss: 3.76246e+06
#     style loss: 970598
#        tv loss: 171949
#     total loss: 4.90501e+06
# Iteration  530/1000
#   content loss: 3.76977e+06
#     style loss: 971382
#        tv loss: 171919
#     total loss: 4.91307e+06
# Iteration  531/1000
#   content loss: 3.7736e+06
#     style loss: 921040
#        tv loss: 171858
#     total loss: 4.8665e+06
# Iteration  532/1000
#   content loss: 3.76892e+06
#     style loss: 885620
#        tv loss: 171674
#     total loss: 4.82621e+06
# Iteration  533/1000
#   content loss: 3.75877e+06
#     style loss: 892815
#        tv loss: 171495
#     total loss: 4.82308e+06
# Iteration  534/1000
#   content loss: 3.7809e+06
#     style loss: 880462
#        tv loss: 171574
#     total loss: 4.83294e+06
# Iteration  535/1000
#   content loss: 3.75104e+06
#     style loss: 915156
#        tv loss: 171143
#     total loss: 4.83734e+06
# Iteration  536/1000
#   content loss: 3.76877e+06
#     style loss: 876198
#        tv loss: 171213
#     total loss: 4.81618e+06
# Iteration  537/1000
#   content loss: 3.77036e+06
#     style loss: 856475
#        tv loss: 171089
#     total loss: 4.79793e+06
# Iteration  538/1000
#   content loss: 3.74334e+06
#     style loss: 902109
#        tv loss: 170715
#     total loss: 4.81616e+06
# Iteration  539/1000
#   content loss: 3.783e+06
#     style loss: 875822
#        tv loss: 170974
#     total loss: 4.8298e+06
# Iteration  540/1000
#   content loss: 3.73926e+06
#     style loss: 901652
#        tv loss: 170449
#     total loss: 4.81136e+06
# Iteration  541/1000
#   content loss: 3.77342e+06
#     style loss: 852415
#        tv loss: 170605
#     total loss: 4.79644e+06
# Iteration  542/1000
#   content loss: 3.7487e+06
#     style loss: 890500
#        tv loss: 170334
#     total loss: 4.80953e+06
# Iteration  543/1000
#   content loss: 3.76543e+06
#     style loss: 880538
#        tv loss: 170242
#     total loss: 4.81621e+06
# Iteration  544/1000
#   content loss: 3.74146e+06
#     style loss: 900696
#        tv loss: 170027
#     total loss: 4.81219e+06
# Iteration  545/1000
#   content loss: 3.7756e+06
#     style loss: 864727
#        tv loss: 170137
#     total loss: 4.81046e+06
# Iteration  546/1000
#   content loss: 3.72765e+06
#     style loss: 912590
#        tv loss: 169659
#     total loss: 4.8099e+06
# Iteration  547/1000
#   content loss: 3.77982e+06
#     style loss: 856124
#        tv loss: 169954
#     total loss: 4.8059e+06
# Iteration  548/1000
#   content loss: 3.72633e+06
#     style loss: 923525
#        tv loss: 169443
#     total loss: 4.8193e+06
# Iteration  549/1000
#   content loss: 3.777e+06
#     style loss: 896537
#        tv loss: 169680
#     total loss: 4.84322e+06
# Iteration  550/1000
#   content loss: 3.71967e+06
#     style loss: 974659
#        tv loss: 169162
#     total loss: 4.8635e+06
# Iteration  551/1000
#   content loss: 3.78613e+06
#     style loss: 899731
#        tv loss: 169599
#     total loss: 4.85546e+06
# Iteration  552/1000
#   content loss: 3.70863e+06
#     style loss: 966990
#        tv loss: 168888
#     total loss: 4.84451e+06
# Iteration  553/1000
#   content loss: 3.78448e+06
#     style loss: 870386
#        tv loss: 169420
#     total loss: 4.82429e+06
# Iteration  554/1000
#   content loss: 3.72433e+06
#     style loss: 916809
#        tv loss: 168868
#     total loss: 4.81001e+06
# Iteration  555/1000
#   content loss: 3.7542e+06
#     style loss: 876253
#        tv loss: 168945
#     total loss: 4.7994e+06
# Iteration  556/1000
#   content loss: 3.75451e+06
#     style loss: 877888
#        tv loss: 168917
#     total loss: 4.80131e+06
# Iteration  557/1000
#   content loss: 3.7297e+06
#     style loss: 903028
#        tv loss: 168571
#     total loss: 4.8013e+06
# Iteration  558/1000
#   content loss: 3.7634e+06
#     style loss: 853021
#        tv loss: 168754
#     total loss: 4.78517e+06
# Iteration  559/1000
#   content loss: 3.73251e+06
#     style loss: 875162
#        tv loss: 168436
#     total loss: 4.77611e+06
# Iteration  560/1000
#   content loss: 3.75329e+06
#     style loss: 866531
#        tv loss: 168407
#     total loss: 4.78823e+06
# Iteration  561/1000
#   content loss: 3.73872e+06
#     style loss: 894563
#        tv loss: 168295
#     total loss: 4.80158e+06
# Iteration  562/1000
#   content loss: 3.74851e+06
#     style loss: 874966
#        tv loss: 168163
#     total loss: 4.79163e+06
# Iteration  563/1000
#   content loss: 3.73488e+06
#     style loss: 870021
#        tv loss: 168045
#     total loss: 4.77294e+06
# Iteration  564/1000
#   content loss: 3.74732e+06
#     style loss: 847475
#        tv loss: 168004
#     total loss: 4.7628e+06
# Iteration  565/1000
#   content loss: 3.73788e+06
#     style loss: 854040
#        tv loss: 167826
#     total loss: 4.75975e+06
# Iteration  566/1000
#   content loss: 3.73559e+06
#     style loss: 856684
#        tv loss: 167728
#     total loss: 4.76e+06
# Iteration  567/1000
#   content loss: 3.7482e+06
#     style loss: 851123
#        tv loss: 167677
#     total loss: 4.767e+06
# Iteration  568/1000
#   content loss: 3.72218e+06
#     style loss: 883370
#        tv loss: 167402
#     total loss: 4.77295e+06
# Iteration  569/1000
#   content loss: 3.75399e+06
#     style loss: 846509
#        tv loss: 167522
#     total loss: 4.76802e+06
# Iteration  570/1000
#   content loss: 3.71514e+06
#     style loss: 886533
#        tv loss: 167126
#     total loss: 4.7688e+06
# Iteration  571/1000
#   content loss: 3.76107e+06
#     style loss: 871273
#        tv loss: 167391
#     total loss: 4.79973e+06
# Iteration  572/1000
#   content loss: 3.69619e+06
#     style loss: 1.02556e+06
#        tv loss: 166745
#     total loss: 4.88849e+06
# Iteration  573/1000
#   content loss: 3.79848e+06
#     style loss: 1.09818e+06
#        tv loss: 167480
#     total loss: 5.06414e+06
# Iteration  574/1000
#   content loss: 3.63333e+06
#     style loss: 1.65896e+06
#        tv loss: 166133
#     total loss: 5.45842e+06
# Iteration  575/1000
#   content loss: 3.87749e+06
#     style loss: 1.76888e+06
#        tv loss: 168154
#     total loss: 5.81453e+06
# Iteration  576/1000
#   content loss: 3.56902e+06
#     style loss: 2.58345e+06
#        tv loss: 165974
#     total loss: 6.31844e+06
# Iteration  577/1000
#   content loss: 3.87256e+06
#     style loss: 1.68709e+06
#        tv loss: 168723
#     total loss: 5.72838e+06
# Iteration  578/1000
#   content loss: 3.72641e+06
#     style loss: 1.7996e+06
#        tv loss: 168261
#     total loss: 5.69426e+06
# Iteration  579/1000
#   content loss: 3.67968e+06
#     style loss: 2.55597e+06
#        tv loss: 167883
#     total loss: 6.40353e+06
# Iteration  580/1000
#   content loss: 3.9165e+06
#     style loss: 2.125e+06
#        tv loss: 170820
#     total loss: 6.21231e+06
# Iteration  581/1000
#   content loss: 3.67846e+06
#     style loss: 2.33578e+06
#        tv loss: 169094
#     total loss: 6.18333e+06
# Iteration  582/1000
#   content loss: 3.77382e+06
#     style loss: 3.0481e+06
#        tv loss: 171040
#     total loss: 6.99295e+06
# Iteration  583/1000
#   content loss: 3.92785e+06
#     style loss: 4.25205e+06
#        tv loss: 173382
#     total loss: 8.35328e+06
# Iteration  584/1000
#   content loss: 3.6668e+06
#     style loss: 4.9408e+06
#        tv loss: 172870
#     total loss: 8.78047e+06
# Iteration  585/1000
#   content loss: 3.89603e+06
#     style loss: 3.63261e+06
#        tv loss: 176094
#     total loss: 7.70473e+06
# Iteration  586/1000
#   content loss: 3.88569e+06
#     style loss: 3.12039e+06
#        tv loss: 178590
#     total loss: 7.18467e+06
# Iteration  587/1000
#   content loss: 3.82444e+06
#     style loss: 2.28235e+06
#        tv loss: 179245
#     total loss: 6.28604e+06
# Iteration  588/1000
#   content loss: 3.90243e+06
#     style loss: 2.62067e+06
#        tv loss: 181644
#     total loss: 6.70474e+06
# Iteration  589/1000
#   content loss: 4.0078e+06
#     style loss: 3.05387e+06
#        tv loss: 184228
#     total loss: 7.24589e+06
# Iteration  590/1000
#   content loss: 3.74436e+06
#     style loss: 3.82096e+06
#        tv loss: 183833
#     total loss: 7.74916e+06
# Iteration  591/1000
#   content loss: 4.22572e+06
#     style loss: 6.65379e+06
#        tv loss: 188020
#     total loss: 1.10675e+07
# Iteration  592/1000
#   content loss: 3.67999e+06
#     style loss: 1.07016e+07
#        tv loss: 186761
#     total loss: 1.45683e+07
# Iteration  593/1000
#   content loss: 4.09667e+06
#     style loss: 4.4061e+06
#        tv loss: 192886
#     total loss: 8.69566e+06
# Iteration  594/1000
#   content loss: 4.08041e+06
#     style loss: 4.1054e+06
#        tv loss: 196928
#     total loss: 8.38274e+06
# Iteration  595/1000
#   content loss: 3.82729e+06
#     style loss: 4.67845e+06
#        tv loss: 199018
#     total loss: 8.70477e+06
# Iteration  596/1000
#   content loss: 4.2261e+06
#     style loss: 4.17469e+06
#        tv loss: 204088
#     total loss: 8.60488e+06
# Iteration  597/1000
#   content loss: 4.03186e+06
#     style loss: 3.8396e+06
#        tv loss: 203918
#     total loss: 8.07538e+06
# Iteration  598/1000
#   content loss: 3.99902e+06
#     style loss: 4.29793e+06
#        tv loss: 205020
#     total loss: 8.50198e+06
# Iteration  599/1000
#   content loss: 4.14339e+06
#     style loss: 2.44882e+06
#        tv loss: 208230
#     total loss: 6.80044e+06
# Iteration  600/1000
#   content loss: 4.18112e+06
#     style loss: 2.82607e+06
#        tv loss: 209300
#     total loss: 7.21648e+06
# Iteration  601/1000
#   content loss: 3.98537e+06
#     style loss: 3.18263e+06
#        tv loss: 207819
#     total loss: 7.37582e+06
# Iteration  602/1000
#   content loss: 4.07816e+06
#     style loss: 2.36149e+06
#        tv loss: 209033
#     total loss: 6.64869e+06
# Iteration  603/1000
#   content loss: 4.2654e+06
#     style loss: 2.60712e+06
#        tv loss: 210391
#     total loss: 7.08291e+06
# Iteration  604/1000
#   content loss: 4.03362e+06
#     style loss: 2.3882e+06
#        tv loss: 207323
#     total loss: 6.62914e+06
# Iteration  605/1000
#   content loss: 4.19275e+06
#     style loss: 2.92701e+06
#        tv loss: 206307
#     total loss: 7.32607e+06
# Iteration  606/1000
#   content loss: 3.97977e+06
#     style loss: 2.99832e+06
#        tv loss: 204891
#     total loss: 7.18298e+06
# Iteration  607/1000
#   content loss: 4.30309e+06
#     style loss: 3.33765e+06
#        tv loss: 206059
#     total loss: 7.8468e+06
# Iteration  608/1000
#   content loss: 3.94917e+06
#     style loss: 4.14961e+06
#        tv loss: 202512
